# %%
import pandas as pd
import os
from google_trans_new import google_translator  
import json
import random
from tqdm import tqdm

# %%
# kb_path = '/home/taindp/PycharmProjects/QASystemOnMedicalKG/data/medical.json'
kb_path = '/home/taindp/PycharmProjects/HHH-An-Online-Question-Answering-System-for-Medical-Questions/Medical_knowledge_graph_establishment/MedicalKBQA/medical_knowledge_base.csv'

# %%
pd.read_csv(kb_path, encoding='gbk')
# Out:
#                                          name  \
# 0                        alveolar proteinosis
# 1                                   pertussis
# 2                           benzene poisoning
# 3                        asthmatic bronchitis
# 4         adult respiratory distress syndrome
# ..                                        ...
# 669                       psoriatic arthritis
# 670          hereditary complement deficiency
# 671                     hereditary angioedema
# 672                              drug allergy
# 673  severe combined immunodeficiency disease
#
#                                                   desc  \
# 0    alveolar proteinosis (pap), also known as rose...
# 1    pertussis (whoopingcough) is an acute respirat...
# 2    benzene is an aromatic hydrocarbon compound ob...
# 3    asthmatoid bronchitis, also known as asthmatic...
# 4    adult respiratory distress syndrome, abbreviat...
# ..                                                 ...
# ...

# %%
def translate_chi2en(origin_text,dest_lang='en'):
    translator = google_translator()  
    translate_text = translator.translate(origin_text,lang_tgt=dest_lang)  
    return translate_text

# %%
def load_json_lines(path):
    list_data = []
    for line in open(path, 'r'):
        try:
            list_data.append(json.loads(line))
        except:
            continue
#     df = pd.DataFrame(list_data)
#     return df
    return list_data

# %%
list_records = load_json_lines(kb_path)

# %%
list_record[0].keys()
# Out:
# dict_keys(['_id', 'name', 'desc', 'category', 'prevent', 'cause', 'symptom', 'yibao_status', 'get_prob', 'get_way', 'acompany', 'cure_department', 'cure_way', 'cure_lasttime', 'cured_prob', 'cost_money', 'check', 'recommand_drug', 'drug_detail'])

# %%
'name,desc,prevent,cause,symptom,acompany,cure_department,cure_way'

# %%
def translate_records(list_records):
    for record in tqdm(list_records):
        list_keys = list(record.keys())
        for key in list_keys:
            if type(record[key]) is str:
                record[key] = translate_chi2en(record[key])
            elif type(record[key]) is list:
                record[key] = [translate_chi2en(item) for item in record[key]]
    return list_records

# %%
translate_records(list_records)
# Out:
#   0%|          | 3/8808 [01:25<69:31:26, 28.43s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-97a290b6b8b5> in <module>
# ----> 1 translate_records(list_records)
#
# <ipython-input-17-3cd47d4b9bd7> in translate_records(list_records)
#       6                 record[key] = translate_chi2en(record[key])
#       7             elif type(record[key]) is list:
# ----> 8                 record[key] = [translate_chi2en(item) for item in record[key]]
#       9     return list_records
#
# <ipython-input-17-3cd47d4b9bd7> in <listcomp>(.0)
#       6                 record[key] = translate_chi2en(record[key])
#       7             elif type(record[key]) is list:
# ----> 8                 record[key] = [translate_chi2en(item) for item in record[key]]
#       9     return list_records
#
# <ipython-input-11-17f7f963d7d8> in translate_chi2en(origin_text, dest_lang)
# ...
